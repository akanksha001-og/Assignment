# %%
# 1) What are the types of Applications?
'''types of Application
    1. Desktop Applications
    2. Web Applications
    3. Mobile Applications
    4. cloud Application'''

# %%
# 2) What is programing?
'''Programming is the process of writing instructions that 
    a computer can understand and follow to perform specific tasks.'''

# %%
# 3) What is Python?
'''Python is a high-level, interpreted programming language that is widely used 
    for software development, data analysis, machine learning, web development, automation, 
    and many other applications.'''

# %%
# 4) Write a Python program to check if a number is positive, negative or zero.
value = int(input("Enter your Value:- "))

if value > 0:
    print("value is Positive")
elif value < 0:
    print("value is Negative")
else:
    print("value is Zero")

# %%
# 5)Write a Python program to get the Factorial number of given numbers.
num = int(input("Enter your value:- "))
factorial = 1
if num < 0:
    print("Factorial Doesn't exist for Negative value")
elif num == 0:
    print("factorial of 0 is 1")
else:
    for i in range(1, num + 1):
        factorial = factorial*i
    print("the factorial of ",num,"is",factorial)

# %%
# 6)Write a Python program to get the Fibonacci series of given range
x = int(input("Enter your value:- "))
a=0
b=1
for i in range(1,x+1):
    p = a+b
    a = b
    b = p
    print(b)

# %%
# 7)How memory is managed in Python?
'''Memory in Python is managed automatically through several key mechanisms:
    Python uses a private heap for all objects and data structures, 
    which is managed internally by the Python memory manager.
        there are two types of memory allocation static for refernces and dynamic for objects'''

# %%
# 8)What is the purpose continuing statement in python? 
'''The purpose of the continue statement in Python is to immediately skip the rest of the code in
    the current iteration of a loop and move to the next iteration, without terminating the loop entirely'''

# %%
# 9) Write python program that swap two number with temp variable
p = int(input("Enter your 1st Number:- "))
q = int(input("Enter your 2nd number:- "))

print("before swapping:")
print("a=",p,"b=",q)

temp = p
p = q
q = temp

print("after swapping:")
print("a=",p,"b=",q)

# %%
#10) Write a Python program to find whether a given number is even 
# or odd, print out an appropriate message to the user.
a = int(input("Enter your number:- "))
if a%2 == 0:
    print("value is number")
else:
    print("value is number")

# %%
# 11) Write a Python program to test whether a passed letter is a vowel 
# or not.
letter = input("Enter your value:-")
if letter in ('a','e','i','o','u'):
    print(letter, "is vowel")
else:
    print(letter, "is not vowel")

# %%
# 12) Write a Python program to sum of three given integers. However, if 
#two values are equal sum will be zero.
def sum(p,q,r):
    if p == q or q == r or r == p:
        return 0
    else:
        return p+q+r
    
p = int(input("1st integers:- "))
q = int(input("2nd integers:- "))
r = int(input("3rd integers:- "))

answer = sum(p,q,r)
print(answer)

# %%
# 13) Write a Python program that will return true if the two given 
#integer values are equal or their sum or difference is 5.
def sum_check(p,q):
    if p == q or (p+q) == 5  or abs(p-q) == 5:
        return True
    else:
        return False

p = int(input("Enter your number:- "))
q = int(input("Enter your number:- "))

result = sum_check(p,q)
print(result)

# %%
# 14)Write a python program to sum of the first n positive integers
p = int(input("Enter your num:- "))
sum_p = p * (p+1) // 2
print("the sum of the first", p, "positive integers is:", sum_p)

# %%
# 15)Write a Python program to calculate the length of a string
p = input("Enter your string:- ")
print("your string lenght is",len(p))

# %%
# 16) Write a Python program to count the number of characters 
#(character frequency) in a string
p = input("Enter your string:- ")
frequency = {}

for char in p:
    if char in frequency:
        frequency[char] += 1
    else:
        frequency[char] = 1

print("character frequency:")
for key, value in frequency.items():
    print(key,":",value)

# %%
# 17)What are negative indexes and why are they used? 
'''Negative indexes in Python are used to access elements of a sequence (like a list, string, or tuple) 
    from the end instead of the beginning.'''

# %%
# 18)Write a Python program to count occurrences of a substring in a string.
string = input("Enter your string: ")
substring = input("Enter your Substring: ")
print("Number of occurnce of substring:",string.count(substring))

# %%
# 19) Write a Python program to count the occurrences of each word in a given sentence
p = input("Enter your Sentence:- ")
words = p.split()

word_count = {}
for word in words:
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1
print("word occurance: ")
for key, value in word_count.items():
    print(key,":", value)

# %%
# 20) Write a Python program to get a single string from two given strings, 
#separated by a space and swap the first two characters of each string.
string1 = input("Enter your 1st  String: ")
string2 = input("Emter your 2nd string: ")

new_string1 = string2[:2] + string1[2:]
new_string2 = string1[:2] + string2[2:]

result = new_string1 + " " + new_string2
print("Resulting string:", result)

# %%
# 21) Write a Python program to add 'in' at the end of a given string (length 
# should be at least 3). If the given string already ends with 'ing' then 
# add 'ly' instead if the string length of the given string is less than 3, 
# leave it unchanged.
string = input("Enter your string:- ")
if len(string)>=3:
    if string.endswith("ing"):
        string += "ly"
    else:
        string += "ing"
else:
    string = string
print("modify string:",string)

# %%
# 22) Write a Python function to reverses a string if its length is a multiple of 4.
def reverse_if_multiple_of_4(string):
    if len(string) % 4 == 0:
        return string[::-1]
    else:
        return string
text = input("Enter a string: ")
print("Result:", reverse_if_multiple_of_4(text))

# %%
# 23) Write a Python program to get a string made of the first 2 and the last 
# 2 chars from a given a string. If the string length is less than 2, return 
# instead of the empty string

def string_both_ends(s):
    if len(s) < 2:
        return ''
    else:
        return s[:2] + s[-2:]
string = input("Enter a string: ")
result = string_both_ends(string)
print("Result:", result)

# %%
# 24)Write a Python function to insert a string in the middle of a string
string = input("Enter your string:- ")
def string_in_string(string)
    a = string%2

# %%
#25)What is List? How will you reverse a list?
'''A List in Python is an ordered, mutable (changeable) collection of items.
It can hold different data types — numbers, strings, other lists, etc.

There are 2 ways to reverse a list
1) reverse()'''
list = [1,2,3,4,5]
list.reverse()
print(list)

'''2) using Slicing'''
num = [1,2,3,4,5]
reversed_list = num[::-1]
print(reversed_list)

# %%
# 26)How will you remove last object from a list?
num = [1,2,3,4,5,6]
num.remove(6)
print(num)

# %%
# 27)Suppose list1 is [2, 33, 222, 14, and 25], what is list1 [-1]?
list = [2,33,222,14,25]
print(list[-1])

# %%
# 28)Differentiate between append () and extend () methods?
'''Answer:-  trough append we can add the value to the end of the  list 
    and trough extend we can add multiple elements to the end of the list '''

# %%
# 29) Write a Python function to get the largest number, smallest num 
#and sum of all from a list
def logical_values(list):
    largest_num = max(list)
    smallest_num = min(list)
    sum_of_num = sum(list)
    print("largest number:-",largest_num)
    print("smallest number:-",smallest_num)
    print("sum of number:-",sum_of_num)

list = [10,55,34,24,786,45,2]

logical_values(list)

# %%
# 30)How will you compare two lists?
'''in python, two list can be compared to check wether they are equal or not equal, 
    we can compare list using comparision operators like
    == :- check if both lists have the same elements in the same order 
    != :- check if lists are different'''

# %%
# 31) Write a Python program to count the number of strings where the string 
'''length is 2 or more and the first and last character are same from a given list 
of strings'''

# %%
# 32)Write a Python program to remove duplicates from a list
list = [1,4,6,4,2,2,3,4,5]
New_list = set(list)
print(New_list)

# %%
# 33)Write a Python program to check a list is empty or not
my_list = []
if not my_list:
    print("The list is empty.")
else:
    print("The list is not empty.")

# %%
# 34) Write a Python function that takes two lists and returns true if they 
# have at least one common member
def common_member(list1, list2):
    for item in list1:
        if item in list2:
            return True
    return False
list1 = [1, 2, 3, 4, 5]
list2 = [5, 6, 7, 8, 9]
print(common_member(list1, list2))

# %%
# 35) Write a Python program to generate and print a list of first and last 5 
# elements where the values are square of numbers between 1 and 30
square_list = [x**2 for x in range(1, 31)]
print("First 5 elements:", square_list[:5])
print("Last 5 elements:", square_list[-5:])

# %%
# 36) Write a Python function that takes a list and returns a new list with 
# unique elements of the first list
def unique_list(lst):
    unique = []
    for item in lst:
        if item not in unique:
            unique.append(item)
    return unique
sample_list = [1, 2, 3, 1, 2, 4, 5, 3]
print("Original list:", sample_list)
print("Unique list:", unique_list(sample_list))

# %%
# 37) Write a Python program to convert a list of characters into a string
chars = ['P', 'y', 't', 'h', 'o', 'n']
result = ''.join(chars)
print("List of characters:", chars)
print("String:", result)

# %%
# 38) Write a Python program to select an item randomly from a list
import random
my_list = [10, 20, 30, 40, 50]
random_item = random.choice(my_list)
print("List:", my_list)
print("Randomly selected item:", random_item)

# %%
# 39) Write a Python program to find the second smallest number in a list

def second_smallest(numbers):
    unique_nums = list(set(numbers))  
    unique_nums.sort()                
    return unique_nums[1]             
num_list = [5, 3, 9, 1, 3, 7, 2]
print("List:", num_list)
print("Second smallest number:", second_smallest(num_list))

# %%
# 40)Write a Python program to get unique values from a list
my_list = [1, 2, 3, 1, 2, 4, 5, 3]
unique_values = list(set(my_list))
print("Original list:", my_list)
print("Unique values:", unique_values)

# %%
# 41) Write a Python program to check whether a list contains a sub list
def is_sublist(main_list, sub_list):
    if not sub_list:
        return True
    for i in range(len(main_list) - len(sub_list) + 1):
        if main_list[i:i + len(sub_list)] == sub_list:
            return True
    return False
main_list = [1, 2, 3, 4, 5, 6]
sub_list = [3, 4, 5]
print("Main list:", main_list)
print("Sub list:", sub_list)
print("Contains sub list?", is_sublist(main_list, sub_list))

# %%
# 42) Write a Python program to split a list into different variables
my_list = [10, 20, 30]
a, b, c = my_list

print("a =", a)
print("b =", b)
print("c =", c)

# %%
# 43)What is tuple? Difference between list and tuple.
'''A tuple is an ordered collection of elements in Python
    the difference between tuple is immutable and list is Mutable.'''

# %%
# 44) Write a Python program to create a tuple with different data types
my_tuple = (25, "Python", 3.14, True, [1, 2, 3], {'a': 10, 'b': 20})
print("Tuple with different data types:")
print(my_tuple)

# %%
# 46) Write a Python program to convert a list of tuples into a dictionary
list_of_tuples = [('a', 100), ('b', 200), ('c', 300)]
result_dict = dict(list_of_tuples)
print("List of tuples:", list_of_tuples)
print("Converted dictionary:", result_dict)

# %%
# 47) How will you create a dictionary using tuples in Python?
tuple_list = [('a', 10), ('b', 20), ('c', 30)]
my_dict = dict(tuple_list)

print("Dictionary created from tuples:", my_dict)

# %%
# 48) Write a Python script to sort (ascending and descending)
# a dictionary by value
my_dict = {'a': 45, 'b': 12, 'c': 78, 'd': 34}
asc_dict = dict(sorted(my_dict.items(), key=lambda item: item[1]))
desc_dict = dict(sorted(my_dict.items(), key=lambda item: item[1], reverse=True))

print("Original dictionary:", my_dict)

# %%
# 49) Write a Python script to concatenate following dictionaries to create a new one
dict1 = {'a': 10, 'b': 20}
dict2 = {'c': 30, 'd': 40}
dict3 = {'e': 50, 'f': 60}
new_dict = {}
for d in (dict1, dict2, dict3):
    new_dict.update(d)

print("Concatenated dictionary:", new_dict)

# %%
# 50) Write a Python script to check if a given key already exists in a dictionary
my_dict = {'a': 10, 'b': 20, 'c': 30}
key = input("Enter a key to check: ")
if key in my_dict:
    print(f"Key '{key}' exists in the dictionary.")
else:
    print(f"Key '{key}' does not exist in the dictionary.")

# %%
# 51)How Do You Traverse Through a Dictionary Object in Python?
my_dict = {'a': 10, 'b': 20, 'c': 30}
for key in my_dict:
    print(key)

# %%
# 52)How Do You Check the Presence of a Key in A Dictionary?
disc = {"a":2,"b":3,"c":4}
if "b" in disc:
    print("key is exists")
else:
    print("key is not found")

# %%
# 53)Write a Python script to print a dictionary where the keys are 
#numbers between 1 and 15
disc = {}
for i in range(1,16):
    disc[i] = i*i
print(disc)

# %%
# 54)Write a Python program to check multiple keys exists in a dictionary
disc = {"a":1,"b":2,"c":3,"d":4}
keys_to_check = ["a","c"]
if all(key in disc for key in keys_to_check):
    print("all keys are exist in the disctionary.")
else:
    print("Some keys are missing in disctionary.")

# %%
# 55)Write a Python script to merge two Python dictionaries
disc1 = {"a":"banana","b":"cherry","c":"mango"}
disc2 = {"D":"strobery","E":"apple","F":"papaya"}
merged_disc = disc1.copy()
merged_disc.update(disc2)
print(merged_disc)

# %%
# 56)Write a Python program to map two lists into a dictionary 
# Sample output: Counter ({'a': 400, 'b': 400,’d’: 400, 'c': 300})
keys = ["a","b","c","d"]
values = [400,400,400,400,300]
result = dict(zip(keys,values))
print(result)

# %%
# 57)Write a Python program to find the highest 3 values in a dictionary
disc = {"a":10,"b":20,"c":8,"d":4}
highest_3 = sorted(disc.values(),reverse=True)[:3]
print("hight_values",highest_3)

# %%
# # 58)Write a Python program to combine values in python list of dictionaries. 
# Sample data: [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount': 
# 300}, o {'item': 'item1', 'amount': 750}] 
# Expected Output:
# • Counter ({'item1': 1150, 'item2': 300})
from collections import Counter

data = [
    {'item': 'item1', 'amount': 400},
    {'item': 'item2', 'amount': 300},
    {'item': 'item1', 'amount': 750}
]

result = Counter()

# Combine values with the same 'item'
for d in data:
    result[d['item']] += d['amount']

print(result)

# %%
# 61)Write a Python function to calculate the factorial of a number (a 
# nonnegative integer)
def factorial(n):
    if n < 0:
        return "Factorial does not exist for negative numbers"
    elif n == 0 or n == 1:
        return 1
    else:
        fact = 1
        for i in range(1, n + 1):
            fact *= i
        return fact
num = int(input("Enter a number: "))
print("The factorial of", num, "is:", factorial(num))

# %%
# 62)Write a Python function to check whether a number is in a given range
def check_range(num, start, end):
    if num in range(start, end + 1):
        return f"{num} is in the range {start} to {end}"
    else:
        return f"{num} is NOT in the range {start} to {end}"
num = int(input("Enter a number: "))
start = int(input("Enter start of range: "))
end = int(input("Enter end of range: "))
print(check_range(num, start, end))

# %%
# 63)Write a Python function to check whether a number is perfect or not
def is_perfect(num):
    if num <= 0:
        return "Enter a positive number"
    sum_of_divisors = 0
    for i in range(1, num):
        if num % i == 0:
            sum_of_divisors += i
    if sum_of_divisors == num:
        return f"{num} is a Perfect Number"
    else:
        return f"{num} is NOT a Perfect Number"
n = int(input("Enter a number: "))
print(is_perfect(n))

# %%
# # 64)Write a Python function that checks whether a passed string is 
# palindrome or not
def is_palindrome(string):
    string = string.replace(" ", "").lower()
    if string == string[::-1]:
        return f"'{string}' is a Palindrome"
    else:
        return f"'{string}' is NOT a Palindrome"
text = input("Enter a string: ")
print(is_palindrome(text))

# %%
# 65)How Many Basic Types of Functions Are Available in Python?
'''1) Built in Function 
   2) User Defined Function'''

# %%
# 66)How can you pick a random item from a list or tuple?
import random
my_list = [10, 20, 30, 40, 50]
random_item = random.choice(my_list)
print("Random item from list:", random_item)
my_tuple = ('apple', 'banana', 'cherry', 'mango')
random_item = random.choice(my_tuple)
print("Random item from tuple:", random_item)

# %%
# 67)How can you pick a random item from a range?
import random as r
r.randrange(1,50)

# %%
# 68)How can you get a random number in python?
'''You can get a random number in Python using the random module'''
import random as r
print(r.randint(1,50))

# %%
# 69)How will you set the starting value in generating random numbers?
import random
random.seed(5)
print(random.randint(1,100))
print(random.randint(1,100))
print(random.randint(1,100))

# %%
# 70) How will you randomize the items of a list in place?
import random as r
list = [1,2,5,7,9]
r.shuffle(list)
print(list)

# %%
# 71)What is File function in python? What are keywords to create 
# and write file
'''In Python, file functions are used to create, read, write, and manage files. 
These functions are mainly handled through the built-in open() function'''
'''open() is use for open the file'''
file = open("test1.txt",'r')
data = file.read()
print(data)
file.close()

# %%
# 72)Write a Python program to read an entire text file.
file = open("example.txt",'r')
data = file.read()
print(data)
file.close()

# %%
# 73)Write a Python program to append text to a file and display the text
with open("example1.txt","a") as file:
    file.write("\nthis is newly appended text.")
with open("example1.txt","r") as file:
    content = file.read()
    print("file content:\n")
    print(content)

# %%
# 74) Write a Python program to read first n lines of a file.
n = int(input("Enter number of line to read: "))
with open("example.txt","r") as file:
    lines = file.readlines()
    print(f"\nfirst {n} lines of the line:")
    for line in lines[:n]:
        print(line, end=" ")

# %%
# 75) Write a Python program to read last n lines of a file.
n = int(input("Enter number of line to read: "))
with open("example.txt","r") as file:
    lines = file.readlines()
    print(f"\n last {n} lines of the line:")
    for line in lines[-n:]:
        print(line, end=" ")

# %%
# 76) Write a Python program to read a file line by line and store it into a list.
with open("example.txt","r") as file:
    line_list = file.readlines()
print("contents of the file stored in the list: ")
print(line_list)

# %%
# 77) Write a Python program to read a file line by line and store it into a variable.
with open("example.txt","r") as file:
    data = file.read()
    print(data)

# %%
# 78) Write a Python program to find the longest words.
with open("example.txt","r") as f:
    words = f.read().split()
max_len = len(max(words, key=len))
longest_words = [word for word in words if len(word) == max_len]
print("longest words:",longest_words)
print("Length of longest word:", max_len)

# %%
# 79) Write a Python program to count the number of lines in a text file.
with open("example.txt","r") as file:
        lines = file.readlines()
line_count = len(lines)
print("Number of lines is:",line_count)

# %%
# 80) Write a Python program to count the frequency of words in a file.
with open("example.txt","r") as f:
    text = f.read()
words = text.split()
word_freq = {}
for word in words:
    word = word.lower()
    word = word.strip(",.!?")
    word_freq[word] = word_freq.get(word, 0) + 1
print("Word Frequency:\n")
for word, count in word_freq.items():
    print(f"{word}: {count}")

# %%
# 81) Write a Python program to write a list to a file.
list = ["Narayan","Laxmi","Mahadev","Paravati","bramha","sarasvati"]
with open("test.txt","w") as f:
    for i in list:
        f.write(i+ "\n")
    
print("List has been Written to 'test.txt' successfuly")

# %%
# 82) Write a Python program to copy the contents of a file to another file.
with open("test.txt","r") as test:
    content = test.read()
with open("test2.txt","w") as test2:
    test2.write(content)
print("file copied successfully test to test2")

print("You can see here copied text:")
with open("test.txt","r") as f:
    print(f.read())

# %%
# 83) Explain Exception handling? What is an Error in Python?

# Exception handling:-
'''Exception Handling means managing runtime errors so that the program doesn't 
    crash — instead, it handles the error gracefully.
    It's done using the try-except block in Python.'''

# Error:-
'''An error in Python means something went wrong in your program that stops it from running properly.
Errors usually happen when you break a rule of the language or when something unexpected occurs'''

# %%
# 84) How many except statements can a try-except block have? Name some built-in exception classes.
'''A try-except block in Python can have more than one except statement, 
    allowing it to handle different types of exceptions separately. There is no strict maximum limit, 
    so you may include as many except clauses as needed to manage various error types in your cod'''

'''Some commonly used built-in exception classes in Python include:
NameError
TypeError
ValueError
ZeroDivisionError
AttributeError
KeyError
IndentationError
IOError'''

# %%
# 85) When will the else part of try-except-else be executed?
'''The else part of a try-except-else block in 
    Python is executed only when no exception occurs in the try block.'''
try:
    x = int(input("Enter your Number:- "))
    print("you entered",x)
except ValueError:
    print("Invalid input! please Enter a number.")
else:
    print("No exception occurred — else block executed.")

# %%
# 86) Can one block of except statements handle multiple exceptions?
'''yes, one except block can handle multiple exceptions in Python.
    we can do this by specifying multiple exception 
    types inside parentheses (tuple) after the except keyword.'''
try:
    x = int(input("Enter a number: "))
    result = 10 / x
except (ZeroDivisionError, ValueError):
    print("Error: Either division by zero or invalid input.")

# %%
# 87) When is the finally block executed?
'''The finally block in Python is always executed, no matter what happens — whether:
    an exception occurs or not,
    the exception is handled or not,
    or even if the program returns or exits early.'''
try:
    x = int(input("Enter a number: "))
    result = 10 / x
except ZeroDivisionError:
    print("Error: Division by zero!")
else:
    print("Division successful!")
finally:
    print("This block always executes.")

# %%
# 88) What happens when "1" == 1 is executed?
'''"1" = is string
    1 = is int
    Python does not automatically convert between different data types when comparing using ==.
    so it checks values and types.
    and here type is defferent so comparistion will be False.'''
print("1"==1)

# %%
# 89) How do you handle exceptions with try/except/finally in Python? Explain with coding snippets.
'''In Python, we can handle exceptions using a combination of try, except, and finally blocks.
    This structure helps we catch errors, handle them gracefully, and ensure cleanup code always runs.'''
try:
    num = int(input("Enter a number: "))
    result = 10 / num
    print("Result:", result)
except ValueError:
    print("Error: Please enter a valid number.")
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
finally:
    print("Execution completed (finally block always runs).")

# %%
# 90) Write a Python program that asks the user to enter only odd numbers; otherwise, it will raise an exception.
try:
    num = int(input("Enter an odd number: "))
    if num % 2 == 0:
        # Raise an exception if the number is even
        raise ValueError("You entered an even number! Please enter only odd numbers.")
    else:
        print("Thank you! You entered an odd number:", num)
except ValueError as e:
    print("Exception:", e)
